# %% [markdown]
# POTENTIAL FORMULATION
#
# The truncated hyperbolic problem guided us to the “extra”
# (delta-function) term in Eq, but it does not explain how we
# missed that term in the first place
# ![image.png](data:image/png;base64,...)
#
# Let’s work out the Lienard Wiechert potentials, and calculate the field more careful
#
# The vector from the (retarded) position of the charge to
# the point r=(s, z), is
# ![image.png](data:image/png;base64,...)
#
# The retarded time is given by
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
# It pays to use Eq (B2) to eliminate the radical:
#
# ![image.png](data:image/png;base64,...)
#
# so
#
#
# ![image.png](data:image/png;base64,...)
#
# Squaring twice of B2 and solving the resulting quadratic yields Eq.
#
# ![image.png](data:image/png;base64,...)
#
# Putting the above Eq, and simplifying we get
#
#
# ![image.png](data:image/png;base64,...)
#
#
# so
#
# ![image.png](data:image/png;base64,...)
#
#
# substuting d in the above equation we will get V
#
#
#
# ![image.png](data:image/png;base64,...)
#
# Meanwhile, the vector potential is
#
# ![image.png](data:image/png;base64,...)
#
#
# and substuting V in the above equation we will get A(vector potential)
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
#
# and similarly doing partial derivation of vector potential with respect to t and substuting in electric field equation we will get the below equation
#
#
# ![image.png](data:image/png;base64,...)
#
#
# which reduces to electric field Eq without the extra term when t = 0.Notice that the derivatives of the theta function contribute
# nothing (we use an overbar to denote the potentials shorn of their h’s)
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# Evidently there is something wrong with the Lienard Wiechert potentials themselves; they too are missing a
# critical term. To fix them, we play the same game as before:
# truncate the hyperbolic motion. We might as well go straight
# to the limit, with the truncation receding to 1; we need
# the potentials of a point charge moving at speed c. There are
# two candidates in the literature10 [which differ by a gauge
# transformation, though both satisfy the Lorenz condition]
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# We also need the “connecting” potentials; our experience
# with the fields [going from Eq. (18) to Eq. (20)] suggests the
# following ansatz
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# It is easy to check, in either case, that we recover the correct
# “extra” term in the field.However, we prefer VII
# and AII because they preserve the Lorenz gauge.
#
#
# The correct potentials for a point charge in hyperbolic
# motion are thus
#
#
#
# ![image.png](data:image/png;base64,...)
