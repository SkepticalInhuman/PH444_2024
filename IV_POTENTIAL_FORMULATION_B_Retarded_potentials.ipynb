# %% [markdown]
# ##Retarded Potentials

# %% [markdown]
# Retarded potential equation:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In this case

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# retarded time for t = 0:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# which gives us

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  *r* = |**r** - **r'**|

# %% [markdown]
# *r* = -ctr = -Tr

# %% [markdown]
# putting t=0 in the equation from Lienard-Wiechert potentials

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# which gives us

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# thus

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# now moving on to the charge density expression

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# thus the integral of density becomes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# integrating with respect to x' and y' would make x' and y' = 0 in the argument of the third delta function. $s^2 = x^2 + y^2$.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Let z0 be the root of f(z') so that the argument of delta function becomes zero.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here z0 cannot be negative thus there is no solution when z<0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# thus $f'(z0) = 1 + (z-z0)/\sqrt{b^2+s^2+{(z-z0)}^2}$ = $1 + (z-z0)/z0$ = z/z0 = $2z^2/(s^2+z^2+b^2)$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# where ai are the roots. Applying the above formula to f(z')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# thus

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# where $θ(z)$ is the step function which equals to 1 if z>0 and 0 otherwise

# %% [markdown]
# which would give us the final potential function

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# this matches the initially derived potential in the Lienard - Wiechert part with T=0.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# but there still seems to be a missing term which can be seen in the corrected potential in the  Lienard - Wiechert part with T=0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This shows that the retarded potentials themselves seems to be incorrect in this case.
